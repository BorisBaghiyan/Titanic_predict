# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df_train = pd.read_csv('train.csv')

# %%
df_test = pd.read_csv('test.csv')

# %%
df_train
# Out:
#      PassengerId HomePlanet CryoSleep     Cabin    Destination   Age    VIP  \
# 0        0001_01     Europa     False     B/0/P    TRAPPIST-1e  39.0  False
# 1        0002_01      Earth     False     F/0/S    TRAPPIST-1e  24.0  False
# 2        0003_01     Europa     False     A/0/S    TRAPPIST-1e  58.0   True
# 3        0003_02     Europa     False     A/0/S    TRAPPIST-1e  33.0  False
# 4        0004_01      Earth     False     F/1/S    TRAPPIST-1e  16.0  False
# ...          ...        ...       ...       ...            ...   ...    ...
# 8688     9276_01     Europa     False    A/98/P    55 Cancri e  41.0   True
# 8689     9278_01      Earth      True  G/1499/S  PSO J318.5-22  18.0  False
# 8690     9279_01      Earth     False  G/1500/S    TRAPPIST-1e  26.0  False
# 8691     9280_01     Europa     False   E/608/S    55 Cancri e  32.0  False
# 8692     9280_02     Europa     False   E/608/S    TRAPPIST-1e  44.0  False
#
# ...

# %%
df_test
# Out:
#      PassengerId HomePlanet CryoSleep     Cabin    Destination   Age    VIP  \
# 0        0013_01      Earth      True     G/3/S    TRAPPIST-1e  27.0  False
# 1        0018_01      Earth     False     F/4/S    TRAPPIST-1e  19.0  False
# 2        0019_01     Europa      True     C/0/S    55 Cancri e  31.0  False
# 3        0021_01     Europa     False     C/1/S    TRAPPIST-1e  38.0  False
# 4        0023_01      Earth     False     F/5/S    TRAPPIST-1e  20.0  False
# ...          ...        ...       ...       ...            ...   ...    ...
# 4272     9266_02      Earth      True  G/1496/S    TRAPPIST-1e  34.0  False
# 4273     9269_01      Earth     False       NaN    TRAPPIST-1e  42.0  False
# 4274     9271_01       Mars      True   D/296/P    55 Cancri e   NaN  False
# 4275     9273_01     Europa     False   D/297/P            NaN   NaN  False
# 4276     9277_01      Earth      True  G/1498/S  PSO J318.5-22  43.0  False
#
# ...

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8693 entries, 0 to 8692
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   PassengerId   8693 non-null   object
#  1   HomePlanet    8492 non-null   object
#  2   CryoSleep     8476 non-null   object
#  3   Cabin         8494 non-null   object
#  4   Destination   8511 non-null   object
#  5   Age           8514 non-null   float64
#  6   VIP           8490 non-null   object
#  7   RoomService   8512 non-null   float64
#  8   FoodCourt     8510 non-null   float64
#  9   ShoppingMall  8485 non-null   float64
#  10  Spa           8510 non-null   float64
#  11  VRDeck        8505 non-null   float64
#  12  Name          8493 non-null   object
#  13  Transported   8693 non-null   bool
# dtypes: bool(1), float64(6), object(7)
# memory usage: 891.5+ KB

# %%
df_train= df_train.drop('PassengerId', axis = 1 )

# %%
df_test = df_test.drop('PassengerId', axis = 1 )

# %%
df_train['HomePlanet'].isna()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 8688    False
# 8689    False
# 8690    False
# 8691    False
# 8692    False
# Name: HomePlanet, Length: 8693, dtype: bool

# %%
df_train['HomePlanet'].value_counts()
# Out:
# HomePlanet
# Earth     4602
# Europa    2131
# Mars      1759
# Name: count, dtype: int64

# %%
df_test['HomePlanet'].value_counts()
# Out:
# HomePlanet
# Earth     2263
# Europa    1002
# Mars       925
# Name: count, dtype: int64

# %%
df_test['HomePlanet'].isna().sum()
# Out:
# np.int64(87)

# %%
df_train['CryoSleep'].isna().sum()
# Out:
# np.int64(217)

# %%
df_test['CryoSleep'].isna().sum()
# Out:
# np.int64(93)

# %%
df_train['Cabin'].isna().sum()
# Out:
# np.int64(199)

# %%
df_test['Cabin'].isna()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 4272    False
# 4273     True
# 4274    False
# 4275    False
# 4276    False
# Name: Cabin, Length: 4277, dtype: bool

# %%
df_train['Destination'].isna().sum()
# Out:
# np.int64(182)

# %%
df_test['Destination'].isna().sum()
# Out:
# np.int64(92)

# %%
df_train['Age'].isna().sum()
# Out:
# np.int64(179)

# %%
df_test['Age'].isna().sum()
# Out:
# np.int64(91)

# %%
df_train['VIP'].isna().sum()
# Out:
# np.int64(203)

# %%
df_test['VIP'].isna().sum()
# Out:
# np.int64(93)

# %%
df_train['HomePlanet'].isna() == True
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 8688    False
# 8689    False
# 8690    False
# 8691    False
# 8692    False
# Name: HomePlanet, Length: 8693, dtype: bool

# %%
df_train = df_train.drop('Cabin', axis = 1)

# %%
df_test = df_test.drop('Cabin', axis = 1)

# %%
df_train
# Out:
#      HomePlanet CryoSleep    Destination   Age    VIP  RoomService  FoodCourt  \
# 0        Europa     False    TRAPPIST-1e  39.0  False          0.0        0.0
# 1         Earth     False    TRAPPIST-1e  24.0  False        109.0        9.0
# 2        Europa     False    TRAPPIST-1e  58.0   True         43.0     3576.0
# 3        Europa     False    TRAPPIST-1e  33.0  False          0.0     1283.0
# 4         Earth     False    TRAPPIST-1e  16.0  False        303.0       70.0
# ...         ...       ...            ...   ...    ...          ...        ...
# 8688     Europa     False    55 Cancri e  41.0   True          0.0     6819.0
# 8689      Earth      True  PSO J318.5-22  18.0  False          0.0        0.0
# 8690      Earth     False    TRAPPIST-1e  26.0  False          0.0        0.0
# 8691     Europa     False    55 Cancri e  32.0  False          0.0     1049.0
# 8692     Europa     False    TRAPPIST-1e  44.0  False        126.0     4688.0
#
# ...

# %%
df_test
# Out:
#      HomePlanet CryoSleep    Destination   Age    VIP  RoomService  FoodCourt  \
# 0         Earth      True    TRAPPIST-1e  27.0  False          0.0        0.0
# 1         Earth     False    TRAPPIST-1e  19.0  False          0.0        9.0
# 2        Europa      True    55 Cancri e  31.0  False          0.0        0.0
# 3        Europa     False    TRAPPIST-1e  38.0  False          0.0     6652.0
# 4         Earth     False    TRAPPIST-1e  20.0  False         10.0        0.0
# ...         ...       ...            ...   ...    ...          ...        ...
# 4272      Earth      True    TRAPPIST-1e  34.0  False          0.0        0.0
# 4273      Earth     False    TRAPPIST-1e  42.0  False          0.0      847.0
# 4274       Mars      True    55 Cancri e   NaN  False          0.0        0.0
# 4275     Europa     False            NaN   NaN  False          0.0     2680.0
# 4276      Earth      True  PSO J318.5-22  43.0  False          0.0        0.0
#
# ...

# %%
df_train['Destination'].value_counts()
# Out:
# Destination
# TRAPPIST-1e      5915
# 55 Cancri e      1800
# PSO J318.5-22     796
# Name: count, dtype: int64

# %%
df_train['VIP'].value_counts()
# Out:
# VIP
# False    8291
# True      199
# Name: count, dtype: int64

# %%
df_train['RoomService'].value_counts()
# Out:
# RoomService
# 0.0       5577
# 1.0        117
# 2.0         79
# 3.0         61
# 4.0         47
#           ...
# 6899.0       1
# 1954.0       1
# 3146.0       1
# 1297.0       1
# 2555.0       1
# Name: count, Length: 1273, dtype: int64

# %%
df_train = df_train.drop('RoomService',axis = 1)
df_test = df_test.drop('RoomService', axis = 1)

# %%
df_train
# Out:
#      HomePlanet CryoSleep    Destination   Age    VIP  FoodCourt  \
# 0        Europa     False    TRAPPIST-1e  39.0  False        0.0
# 1         Earth     False    TRAPPIST-1e  24.0  False        9.0
# 2        Europa     False    TRAPPIST-1e  58.0   True     3576.0
# 3        Europa     False    TRAPPIST-1e  33.0  False     1283.0
# 4         Earth     False    TRAPPIST-1e  16.0  False       70.0
# ...         ...       ...            ...   ...    ...        ...
# 8688     Europa     False    55 Cancri e  41.0   True     6819.0
# 8689      Earth      True  PSO J318.5-22  18.0  False        0.0
# 8690      Earth     False    TRAPPIST-1e  26.0  False        0.0
# 8691     Europa     False    55 Cancri e  32.0  False     1049.0
# 8692     Europa     False    TRAPPIST-1e  44.0  False     4688.0
#
#       ShoppingMall     Spa  VRDeck               Name  Transported
# 0              0.0     0.0     0.0    Maham Ofracculy        False
# ...

# %%
df_train['ShoppingMall'].value_counts()
# Out:
# ShoppingMall
# 0.0        5587
# 1.0         153
# 2.0          80
# 3.0          59
# 4.0          45
#            ...
# 563.0         1
# 23492.0       1
# 816.0         1
# 1970.0        1
# 204.0         1
# Name: count, Length: 1115, dtype: int64

# %%
df_train = df_train.drop('ShoppingMall',axis = 1)
df_test = df_test.drop('ShoppingMall', axis = 1)

# %%
df_train
# Out:
#      HomePlanet CryoSleep    Destination   Age    VIP  FoodCourt     Spa  \
# 0        Europa     False    TRAPPIST-1e  39.0  False        0.0     0.0
# 1         Earth     False    TRAPPIST-1e  24.0  False        9.0   549.0
# 2        Europa     False    TRAPPIST-1e  58.0   True     3576.0  6715.0
# 3        Europa     False    TRAPPIST-1e  33.0  False     1283.0  3329.0
# 4         Earth     False    TRAPPIST-1e  16.0  False       70.0   565.0
# ...         ...       ...            ...   ...    ...        ...     ...
# 8688     Europa     False    55 Cancri e  41.0   True     6819.0  1643.0
# 8689      Earth      True  PSO J318.5-22  18.0  False        0.0     0.0
# 8690      Earth     False    TRAPPIST-1e  26.0  False        0.0     1.0
# 8691     Europa     False    55 Cancri e  32.0  False     1049.0   353.0
# 8692     Europa     False    TRAPPIST-1e  44.0  False     4688.0     0.0
#
#       VRDeck               Name  Transported
# 0        0.0    Maham Ofracculy        False
# ...

# %%
df_train['FoodCourt'].value_counts()
# Out:
# FoodCourt
# 0.0        5456
# 1.0         116
# 2.0          75
# 3.0          53
# 4.0          53
#            ...
# 1585.0        1
# 749.0         1
# 1961.0        1
# 522.0         1
# 14773.0       1
# Name: count, Length: 1507, dtype: int64

# %%
df_train = df_train.drop('FoodCourt', axis = 1)

# %%
df_test = df_test.drop('FoodCourt', axis = 1)

# %%
df_train
# Out:
#      HomePlanet CryoSleep    Destination   Age    VIP     Spa  VRDeck  \
# 0        Europa     False    TRAPPIST-1e  39.0  False     0.0     0.0
# 1         Earth     False    TRAPPIST-1e  24.0  False   549.0    44.0
# 2        Europa     False    TRAPPIST-1e  58.0   True  6715.0    49.0
# 3        Europa     False    TRAPPIST-1e  33.0  False  3329.0   193.0
# 4         Earth     False    TRAPPIST-1e  16.0  False   565.0     2.0
# ...         ...       ...            ...   ...    ...     ...     ...
# 8688     Europa     False    55 Cancri e  41.0   True  1643.0    74.0
# 8689      Earth      True  PSO J318.5-22  18.0  False     0.0     0.0
# 8690      Earth     False    TRAPPIST-1e  26.0  False     1.0     0.0
# 8691     Europa     False    55 Cancri e  32.0  False   353.0  3235.0
# 8692     Europa     False    TRAPPIST-1e  44.0  False     0.0    12.0
#
#                    Name  Transported
# 0       Maham Ofracculy        False
# 1          Juanna Vines         True
# ...

# %%
df_train = df_train.drop('Name', axis = 1)

# %%
df_test = df_test.drop('Name', axis = 1)

# %%
df_train
# Out:
#      HomePlanet CryoSleep    Destination   Age    VIP     Spa  VRDeck  \
# 0        Europa     False    TRAPPIST-1e  39.0  False     0.0     0.0
# 1         Earth     False    TRAPPIST-1e  24.0  False   549.0    44.0
# 2        Europa     False    TRAPPIST-1e  58.0   True  6715.0    49.0
# 3        Europa     False    TRAPPIST-1e  33.0  False  3329.0   193.0
# 4         Earth     False    TRAPPIST-1e  16.0  False   565.0     2.0
# ...         ...       ...            ...   ...    ...     ...     ...
# 8688     Europa     False    55 Cancri e  41.0   True  1643.0    74.0
# 8689      Earth      True  PSO J318.5-22  18.0  False     0.0     0.0
# 8690      Earth     False    TRAPPIST-1e  26.0  False     1.0     0.0
# 8691     Europa     False    55 Cancri e  32.0  False   353.0  3235.0
# 8692     Europa     False    TRAPPIST-1e  44.0  False     0.0    12.0
#
#       Transported
# 0           False
# 1            True
# 2           False
# 3           False
# 4            True
# ...

# %%
df_train['Spa'].value_counts()
# Out:
# Spa
# 0.0       5324
# 1.0        146
# 2.0        105
# 5.0         53
# 3.0         53
#           ...
# 780.0        1
# 800.0        1
# 1239.0       1
# 3761.0       1
# 5025.0       1
# Name: count, Length: 1327, dtype: int64

# %%
df_train = df_train.drop('Spa',axis = 1)
df_test = df_test.drop('Spa', axis = 1)

# %%
df_train
# Out:
#      HomePlanet CryoSleep    Destination   Age    VIP  VRDeck  Transported
# 0        Europa     False    TRAPPIST-1e  39.0  False     0.0        False
# 1         Earth     False    TRAPPIST-1e  24.0  False    44.0         True
# 2        Europa     False    TRAPPIST-1e  58.0   True    49.0        False
# 3        Europa     False    TRAPPIST-1e  33.0  False   193.0        False
# 4         Earth     False    TRAPPIST-1e  16.0  False     2.0         True
# ...         ...       ...            ...   ...    ...     ...          ...
# 8688     Europa     False    55 Cancri e  41.0   True    74.0        False
# 8689      Earth      True  PSO J318.5-22  18.0  False     0.0        False
# 8690      Earth     False    TRAPPIST-1e  26.0  False     0.0         True
# 8691     Europa     False    55 Cancri e  32.0  False  3235.0        False
# 8692     Europa     False    TRAPPIST-1e  44.0  False    12.0         True
#
# [8693 rows x 7 columns]

# %%
df_train['VRDeck'].value_counts()
# Out:
# VRDeck
# 0.0       5495
# 1.0        139
# 2.0         70
# 3.0         56
# 5.0         51
#           ...
# 471.0        1
# 2064.0       1
# 802.0        1
# 1556.0       1
# 5057.0       1
# Name: count, Length: 1306, dtype: int64

# %%
df_train = df_train.drop('VRDeck',axis = 1)
df_test = df_test.drop('VRDeck', axis = 1)

# %%
df_train
# Out:
#      HomePlanet CryoSleep    Destination   Age    VIP  Transported
# 0        Europa     False    TRAPPIST-1e  39.0  False        False
# 1         Earth     False    TRAPPIST-1e  24.0  False         True
# 2        Europa     False    TRAPPIST-1e  58.0   True        False
# 3        Europa     False    TRAPPIST-1e  33.0  False        False
# 4         Earth     False    TRAPPIST-1e  16.0  False         True
# ...         ...       ...            ...   ...    ...          ...
# 8688     Europa     False    55 Cancri e  41.0   True        False
# 8689      Earth      True  PSO J318.5-22  18.0  False        False
# 8690      Earth     False    TRAPPIST-1e  26.0  False         True
# 8691     Europa     False    55 Cancri e  32.0  False        False
# 8692     Europa     False    TRAPPIST-1e  44.0  False         True
#
# [8693 rows x 6 columns]

# %%
df_train['HomePlanet'] = df_train['HomePlanet'].fillna(df_train['HomePlanet'])

# %%
df_test['HomePlanet'] = df_test['HomePlanet'].fillna(df_test['HomePlanet'])

# %%
df_train['CryoSleep'] = df_train['CryoSleep'].fillna(df_train['CryoSleep'])

# %%
df_test['CryoSleep'] = df_test['CryoSleep'].fillna(df_test['CryoSleep'])

# %%
df_train['Destination'] = df_train['Destination'].fillna(df_train['Destination'])

# %%
df_test['Destination'] = df_test['Destination'].fillna(df_test['Destination'])

# %%
df_train['VIP'] = df_train['VIP'].fillna(df_train['VIP'])

# %%
df_test['VIP'] = df_test['VIP'].fillna(df_test['VIP'])

# %%
df_train['Age'].isna().sum()
# Out:
# np.int64(179)

# %%
df_train['Age'] = df_train['Age'].fillna(df_train['Age'].median())

# %%
df_test['Age'] = df_test['Age'].fillna(df_test['Age'].median())

# %%
df_train['Age'].isna().sum()
# Out:
# np.int64(0)

# %%
from sklearn.preprocessing import LabelEncoder

# %%
label = LabelEncoder()

# %%
df_train['HomePlanet']=label.fit_transform(df_train['HomePlanet'])

# %%
df_test['HomePlanet']=label.transform(df_test['HomePlanet'])

# %%
df_train['CryoSleep']=label.fit_transform(df_train['CryoSleep'])

# %%
df_test['CryoSleep']=label.transform(df_test['CryoSleep'])

# %%
df_train['Destination']=label.fit_transform(df_train['Destination'])

# %%
df_test['Destination']=label.transform(df_test['Destination'])

# %%
df_train['VIP']=label.fit_transform(df_train['VIP'])

# %%
df_test['VIP']=label.transform(df_test['VIP'])

# %%
df_train['Transported']=label.fit_transform(df_train['Transported'])

# %%
df_train
# Out:
#       HomePlanet  CryoSleep  Destination   Age  VIP  Transported
# 0              1          0            2  39.0    0            0
# 1              0          0            2  24.0    0            1
# 2              1          0            2  58.0    1            0
# 3              1          0            2  33.0    0            0
# 4              0          0            2  16.0    0            1
# ...          ...        ...          ...   ...  ...          ...
# 8688           1          0            0  41.0    1            0
# 8689           0          1            1  18.0    0            0
# 8690           0          0            2  26.0    0            1
# 8691           1          0            0  32.0    0            0
# 8692           1          0            2  44.0    0            1
#
# [8693 rows x 6 columns]

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8693 entries, 0 to 8692
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   HomePlanet   8693 non-null   int64
#  1   CryoSleep    8693 non-null   int64
#  2   Destination  8693 non-null   int64
#  3   Age          8693 non-null   float64
#  4   VIP          8693 non-null   int64
#  5   Transported  8693 non-null   int64
# dtypes: float64(1), int64(5)
# memory usage: 407.6 KB

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix, ConfusionMatrixDisplay

# %%
from sklearn.model_selection import train_test_split

# %%
X = df_train.drop('Transported', axis=1)
y = df_train['Transported']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
new_df1 = pd.concat([df_train[df_train['VIP'] == 1].head(300), df_train[df_train['VIP'] == 0].head(300)], ignore_index=True)

# %%
new_df2 = pd.concat([df_test[df_test['VIP'] == 1].head(100), df_test[df_test['VIP'] == 0].head(100)], ignore_index=True)

# %%
accuracy_list = []
k_list = []
for i in range(1, 50):
    model = KNeighborsClassifier(n_neighbors=i)
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)
    accuracy_list.append(accuracy_score(y_test, y_pred))
    k_list.append(i)

# %%
plt.plot(k_list, accuracy_list)
plt.xlim(10, 20)
# Out:
# (10.0, 20.0)

# %%
model = KNeighborsClassifier(n_neighbors=12)
model.fit(X_train, y_train)
y_pred = model.predict(X_test)

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.67      0.80      0.73      1424
#            1       0.75      0.62      0.68      1445
#
#     accuracy                           0.71      2869
#    macro avg       0.71      0.71      0.70      2869
# weighted avg       0.71      0.71      0.70      2869

# %%
from sklearn.model_selection import GridSearchCV

# %%
params = {
    'n_neighbors':[i for i in range(1, 15)],
    'metric': ["euclidean", "manhattan", "chebyshev", "minkowski", "mahalanobis"],
}

# %%
final_model = GridSearchCV(model, param_grid=params, cv=3, verbose=2)

# %%
final_model.fit(X_train, y_train)
# Out:
# Fitting 3 folds for each of 70 candidates, totalling 210 fits
# [CV] END ....................metric=euclidean, n_neighbors=1; total time=   0.0s
# [CV] END ....................metric=euclidean, n_neighbors=1; total time=   0.0s
# [CV] END ....................metric=euclidean, n_neighbors=1; total time=   0.0s
# [CV] END ....................metric=euclidean, n_neighbors=2; total time=   0.0s
# [CV] END ....................metric=euclidean, n_neighbors=2; total time=   0.0s
# [CV] END ....................metric=euclidean, n_neighbors=2; total time=   0.0s
# [CV] END ....................metric=euclidean, n_neighbors=3; total time=   0.0s
# [CV] END ....................metric=euclidean, n_neighbors=3; total time=   0.0s
# [CV] END ....................metric=euclidean, n_neighbors=3; total time=   0.0s
# [CV] END ....................metric=euclidean, n_neighbors=4; total time=   0.0s
# [CV] END ....................metric=euclidean, n_neighbors=4; total time=   0.0s
# ...

# %%
final_model.best_params_
# Out:
# {'metric': 'manhattan', 'n_neighbors': 13}

# %%
final_model.best_score_
# Out:
# np.float64(0.7087924886096596)

# %%
y_pred = final_model.predict(X_test)

# %%
y_pred
# Out:
# array([0, 0, 1, ..., 0, 0, 1], shape=(2869,))
